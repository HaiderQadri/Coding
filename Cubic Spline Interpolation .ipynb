# %%
pip install scipy
# Out:
# Requirement already satisfied: scipy in c:\users\qadri\anaconda3\lib\site-packages (1.7.1)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in c:\users\qadri\anaconda3\lib\site-packages (from scipy) (1.20.3)

# %%
pip install gekko
# Out:
# Collecting gekkoNote: you may need to restart the kernel to use updated packages.
#   Downloading gekko-1.0.4-py3-none-any.whl (14.1 MB)
# Requirement already satisfied: numpy>=1.8 in c:\users\qadri\anaconda3\lib\site-packages (from gekko) (1.20.3)
# Installing collected packages: gekko
# Successfully installed gekko-1.0.4

# %%
from scipy import interpolate
import numpy as np
import matplotlib.pyplot as plt

# %%
def cubicinterpolation():
    x_pts = np.linspace(0,2*np.pi,10)   # 10 equidistant coords from 0 to 10
    y_pts = np.sin(x_pts)
    x_vals = np.linspace(0,2*np.pi,50)  # 50 desired points
    
    splines = interpolate.splrep(x_pts,y_pts)
    y_vals = interpolate.splev(x_vals,splines) # cubic interpolation
    
    plt.plot(x_pts,y_pts,'or') # plot known data project
    plt.plot(x_vals,y_vals,'--x')# plot interpolated points
    plt.show()

# %%
print(cubicinterpolation())
# Out:
# None

# %%
def cubicinterpolation():
    x_pts = np.linspace(0,2*np.pi,10)  # 10 equidistant coords from 0 to 10
    y_pts = np.sin(x_pts)
    x_vals = np.linspace(0,2*np.pi,50)  # 50 desired points
    
    f = interpolate.interp1d(x_pts,y_pts,'cubic')
    y_vals = f(x_vals) # cubic interpolation
    
    plt.plot(x_pts,y_pts,'ob') # plot known data project
    plt.plot(x_vals,y_vals,'-xr')# plot interpolated points
    plt.show()

# %%
print(cubicinterpolation())
# Out:
# None
